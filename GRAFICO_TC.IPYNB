# %%
#Correcto
import pandas as pd
import matplotlib.pyplot as plt

    # Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon.xlsx"

    # Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

    # Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

    # Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

    # Configurar subplots
fig, axs = plt.subplots(num_filas, 1, figsize=(10, 5 * num_filas))

    # Iterar sobre las filas
for i in range(num_filas):
        # Obtener datos para el eje X
        x_data = df.columns[2:]

        # Obtener datos para el eje Y y convertir a tipo numérico
        y_data = pd.to_numeric(df.iloc[i, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

        # Graficar dispersión con líneas rectas y marcadores
        axs[i].plot(x_data, y_data, marker='o', linestyle='-')

        # Configurar etiquetas y título
        axs[i].set_xlabel('Periodos')
        axs[i].set_ylabel('Concentración de Radón (Bq/m3)')
        axs[i].set_title(f'Gráfico {i + 1}')

    # Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4645.6                          595.9
# 1                           94.8                         5438.1
# 2                         5760.6                         5032.5
# 3                         6629.4                         4348.8
# 4                         9592.4                         8303.4
#
#    Radon concentration_periodo_4
# 0                         1863.8
# 1                         3259.4
# 2                         4721.2
# 3                         4658.3
# 4                         1886.7

# %%
#CORRECTO (12 FIGURAS CON NOMBRE DE CADA POZO)
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(num_filas, 1, figsize=(10, 5 * num_filas))

# Iterar sobre las filas
for i in range(num_filas):
    # Obtener datos para el eje X
    x_data = df.columns[2:]

    # Obtener datos para el eje Y y convertir a tipo numérico
    y_data = pd.to_numeric(df.iloc[i, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

    # Obtener el nombre del pozo para usarlo como título
    nombre_pozo = df.iloc[i, 0]

    # Graficar dispersión con líneas rectas y marcadores
    axs[i].plot(x_data, y_data, marker='o', linestyle='-')

    # Configurar etiquetas y título
    axs[i].set_xlabel('Periodos')
    axs[i].set_ylabel('Concentración de Radón (Bq/m3)')
    axs[i].set_title(f'Pozo {nombre_pozo}')

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4645.6                          595.9
# 1                           94.8                         5438.1
# 2                         5760.6                         5032.5
# 3                         6629.4                         4348.8
# 4                         9592.4                         8303.4
#
#    Radon concentration_periodo_4
# 0                         1863.8
# 1                         3259.4
# 2                         4721.2
# 3                         4658.3
# 4                         1886.7

# %%
#CODIGO FINAL PARA TC_PRIMERAS 4 SEMANAS (GRAFICO DE DISPERSIÓN CON LINEAS RECTAS Y MARCADORES)
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon_16_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Obtener el nombre del pozo para usarlo como título
            nombre_pozo = df.iloc[index, 0]

            # Graficar dispersión con líneas rectas y marcadores
            axs[i, j].plot(x_data, y_data, marker='o', linestyle='-')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_title(f'Pozo {nombre_pozo}')
# Agregar título general

plt.suptitle("Twin chamber - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4593.4                          263.5
# 1                           42.6                         5105.7
# 2                         5708.4                         4700.0
# 3                         6577.2                         4016.4
# 4                         9540.2                         7970.9
#
#    Radon concentration_periodo_4
# 0                         1561.3
# 1                         2956.9
# 2                         4418.7
# 3                         4355.9
# 4                         1584.2

# %%
#CODIGO FINAL PARA TC_PRIMERAS 4 SEMANAS (GRAFICO DE BARRAS CON LINEAS RECTAS Y MARCADORES)

import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon_16_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Obtener el nombre del pozo para usarlo como título
            nombre_pozo = df.iloc[index, 0]

            # Graficar barras con líneas y marcadores (ajustando el ancho de las barras)
            axs[i, j].bar(x_data, y_data, color='cornflowerblue', alpha=0.7, width=0.3, label='Barras')
            axs[i, j].plot(x_data, y_data, marker='*', linestyle='-', color='red', label='Línea con Marcadores')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_title(f'Pozo {nombre_pozo}')

# Agregar título general
plt.suptitle("Twin chamber - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4593.4                          263.5
# 1                           42.6                         5105.7
# 2                         5708.4                         4700.0
# 3                         6577.2                         4016.4
# 4                         9540.2                         7970.9
#
#    Radon concentration_periodo_4
# 0                         1561.3
# 1                         2956.9
# 2                         4418.7
# 3                         4355.9
# 4                         1584.2

# %% [markdown]
# GRAFICO DE LINEAS_FINAL_SIN ESCALADO

# %%
#CODIGO FINAL PARA TC_PRIMERAS 4 SEMANAS (GRAFICO DE DISPERSIÓN CON LINEAS RECTAS Y MARCADORES)
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon_16_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Obtener el nombre del pozo para usarlo como título
            nombre_pozo = df.iloc[index, 0]

            # Graficar dispersión con líneas rectas y marcadores
            axs[i, j].plot(x_data, y_data, marker='o', linestyle='-')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_title(f'Pozo {nombre_pozo}')
# Agregar título general

plt.suptitle("Twin chamber - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4593.4                          263.5
# 1                           42.6                         5105.7
# 2                         5708.4                         4700.0
# 3                         6577.2                         4016.4
# 4                         9540.2                         7970.9
#
#    Radon concentration_periodo_4
# 0                         1561.3
# 1                         2956.9
# ...

# %% [markdown]
# GRAFICO DE BARRAS_ FINAL_ SIN ESCALADO

# %%
#CODIGO FINAL PARA TC_PRIMERAS 4 SEMANAS (GRAFICO DE BARRAS CON LINEAS RECTAS Y MARCADORES)

import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon_16_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Obtener el nombre del pozo para usarlo como título
            nombre_pozo = df.iloc[index, 0]

            # Graficar barras con líneas y marcadores (ajustando el ancho de las barras)
            axs[i, j].bar(x_data, y_data, color='cornflowerblue', alpha=0.7, width=0.3, label='Barras')
            axs[i, j].plot(x_data, y_data, marker='*', linestyle='-', color='red', label='Línea con Marcadores')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_title(f'Pozo {nombre_pozo}')

# Agregar título general
plt.suptitle("Twin chamber - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4593.4                          263.5
# 1                           42.6                         5105.7
# 2                         5708.4                         4700.0
# 3                         6577.2                         4016.4
# 4                         9540.2                         7970.9
#
#    Radon concentration_periodo_4
# 0                         1561.3
# 1                         2956.9
# ...

# %% [markdown]
# GRAFICO_DE_LINEAS_FINAL_ESCALADO___TC

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon_16_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Obtener el valor máximo entre todos los gráficos
max_y_value = df.iloc[:, 2:].apply(pd.to_numeric, errors='coerce').max().max()

# Definir un factor para ajustar la escala máxima (por ejemplo, 1.05 para un 5% más alto)
escala_maxima_factor = 1.05

# Calcular la escala máxima ajustada
escala_maxima_ajustada = max_y_value * escala_maxima_factor

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Graficar dispersión con líneas rectas y marcadores
            axs[i, j].plot(x_data, y_data, marker='o', linestyle='-')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_ylim([0, escala_maxima_ajustada])  # Establecer límites en el eje Y
            axs[i, j].set_title(f'Pozo {df.iloc[index, 0]}')

# Agregar título general
plt.suptitle("Twin chamber - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4593.4                          263.5
# 1                           42.6                         5105.7
# 2                         5708.4                         4700.0
# 3                         6577.2                         4016.4
# 4                         9540.2                         7970.9
#
#    Radon concentration_periodo_4
# 0                         1561.3
# 1                         2956.9
# ...

# %% [markdown]
# GRAFICO_DE_BARRAS_Y_LINEAS_FINAL_ESCALADO___TC

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\TC\primeros_4_periodos_tc_solo_radon_16_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Obtener el valor máximo entre todos los gráficos
max_y_value = df.iloc[:, 2:].apply(pd.to_numeric, errors='coerce').max().max()

# Definir un factor para ajustar la escala máxima (por ejemplo, 1.05 para un 5% más alto)
escala_maxima_factor = 1.05

# Calcular la escala máxima ajustada
escala_maxima_ajustada = max_y_value * escala_maxima_factor

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Graficar barras con líneas y marcadores (ajustando el ancho de las barras)
            axs[i, j].bar(x_data, y_data, color='cornflowerblue', alpha=0.7, width=0.3, label='Barras')
            axs[i, j].plot(x_data, y_data, marker='*', linestyle='-', color='red', label='Línea con Marcadores')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_ylim([0, escala_maxima_ajustada])  # Establecer límites en el eje Y
            axs[i, j].set_title(f'Pozo {df.iloc[index, 0]}')

# Agregar título general
plt.suptitle("Twin chamber - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     2                           TC02                         5402.0
# 1     4                           TC04                        11719.0
# 2     6                           TC06                         5152.5
# 3     7                           TC07                         3900.1
# 4     9                           TC09                         3473.0
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         4593.4                          263.5
# 1                           42.6                         5105.7
# 2                         5708.4                         4700.0
# 3                         6577.2                         4016.4
# 4                         9540.2                         7970.9
#
#    Radon concentration_periodo_4
# 0                         1561.3
# 1                         2956.9
# ...

# %% [markdown]
# GRAFICO_DE_LINEAS_FINAL_ESCALADO___G3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\G3\primeros_4_periodos_G3_solo_radon_22_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Obtener el valor máximo entre todos los gráficos
max_y_value = df.iloc[:, 2:].apply(pd.to_numeric, errors='coerce').max().max()

# Definir un factor para ajustar la escala máxima (por ejemplo, 1.05 para un 5% más alto)
escala_maxima_factor = 1.05

# Calcular la escala máxima ajustada
escala_maxima_ajustada = max_y_value * escala_maxima_factor

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Graficar dispersión con líneas rectas y marcadores
            axs[i, j].plot(x_data, y_data, marker='o', linestyle='-')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_ylim([0, escala_maxima_ajustada])  # Establecer límites en el eje Y
            axs[i, j].set_title(f'Pozo {df.iloc[index, 0]}')

# Agregar título general
plt.suptitle("G3 - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     1                          G3-01                         1780.9
# 1     3                          G3-03                         1046.6
# 2     5                          G3-05                         1855.5
# 3     8                          G3-08                         1200.1
# 4    10                          G3-10                         1036.4
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         1498.8                         2414.0
# 1                         2055.9                         1630.5
# 2                         1111.3                         2174.1
# 3                         1083.4                         1286.3
# 4                         1664.2                         3024.5
#
#    Radon concentration_periodo_4
# 0                         3374.4
# 1                          284.6
# ...

# %% [markdown]
# GRAFICO_DE_BARRAS_Y_LINEAS_FINAL_ESCALADO___G3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\G3\primeros_4_periodos_G3_solo_radon_22_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Obtener el valor máximo entre todos los gráficos
max_y_value = df.iloc[:, 2:].apply(pd.to_numeric, errors='coerce').max().max()

# Definir un factor para ajustar la escala máxima (por ejemplo, 1.05 para un 5% más alto)
escala_maxima_factor = 1.05

# Calcular la escala máxima ajustada
escala_maxima_ajustada = max_y_value * escala_maxima_factor

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Configurar subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))  # 4 filas, 3 columnas

# Iterar sobre las filas y columnas
for i in range(4):
    for j in range(3):
        # Calcular el índice correspondiente en el DataFrame
        index = i * 3 + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Graficar barras con líneas y marcadores (ajustando el ancho de las barras)
            axs[i, j].bar(x_data, y_data, color='cornflowerblue', alpha=0.7, width=0.3, label='Barras')
            axs[i, j].plot(x_data, y_data, marker='*', linestyle='-', color='red', label='Línea con Marcadores')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_ylim([0, escala_maxima_ajustada])  # Establecer límites en el eje Y
            axs[i, j].set_title(f'Pozo {df.iloc[index, 0]}')

# Agregar título general
plt.suptitle("G3 - Primeros cuatro periodos - Cusco", fontsize=16)

# Ajustar diseño y mostrar gráficos
plt.tight_layout()
plt.show()
# Out:
# Número de filas: 12
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     1                          G3-01                         1780.9
# 1     3                          G3-03                         1046.6
# 2     5                          G3-05                         1855.5
# 3     8                          G3-08                         1200.1
# 4    10                          G3-10                         1036.4
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         1498.8                         2414.0
# 1                         2055.9                         1630.5
# 2                         1111.3                         2174.1
# 3                         1083.4                         1286.3
# 4                         1664.2                         3024.5
#
#    Radon concentration_periodo_4
# 0                         3374.4
# 1                          284.6
# ...

# %% [markdown]
# GRAFICO_DE_LINEAS_FINAL_ESCALADO___RO

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\RO\primeros_4_periodos_RO_solo_radon_22_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Obtener el valor máximo entre todos los gráficos
max_y_value = df.iloc[:, 2:].apply(pd.to_numeric, errors='coerce').max().max()

# Definir un factor para ajustar la escala máxima (por ejemplo, 1.05 para un 5% más alto)
escala_maxima_factor = 1.05

# Calcular la escala máxima ajustada
escala_maxima_ajustada = max_y_value * escala_maxima_factor

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Calcular el número de filas y columnas para los subplots
num_filas_subplot = (num_filas // 3) + (num_filas % 3 > 0)
num_columnas_subplot = 3

# Configurar subplots
fig, axs = plt.subplots(num_filas_subplot, num_columnas_subplot, figsize=(15, 4 * num_filas_subplot))

# Iterar sobre las filas y columnas
for i in range(num_filas_subplot):
    for j in range(num_columnas_subplot):
        # Calcular el índice correspondiente en el DataFrame
        index = i * num_columnas_subplot + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Graficar dispersión con líneas rectas y marcadores
            axs[i, j].plot(x_data, y_data, marker='o', linestyle='-')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_ylim([0, escala_maxima_ajustada])  # Establecer límites en el eje Y
            axs[i, j].set_title(f'Pozo {df.iloc[index, 0]}')

# Ajustar espacio entre el título general y los subplots
plt.subplots_adjust(top=0.9)

# Agregar título general con espacio entre los subplots
plt.suptitle("RADOUT - Primeros cuatro periodos - Cusco", fontsize=16, y=0.92)

# Ajustar diseño y mostrar gráficos
plt.tight_layout(rect=[0, 0.03, 1, 0.93])
plt.show()
# Out:
# Número de filas: 18
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     1                          RO-01                         8737.8
# 1     2                          RO-02                         6420.9
# 2     3                          RO-03                         7684.0
# 3     4                          RO-04                         8521.3
# 4     5                          RO-05                         8458.6
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         9278.4                        10239.1
# 1                         6383.4                         6835.7
# 2                         8535.1                         8342.4
# 3                         9097.6                        10136.6
# 4                         9089.0                        10405.7
#
#    Radon concentration_periodo_4
# 0                         9716.5
# 1                         6556.6
# ...

# %% [markdown]
# GRAFICO_DE_BARRAS_Y_LINEAS_FINAL_ESCALADO___RO

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ruta del archivo Excel
archivo_excel = r"C:\Users\Bruce\Desktop\ARTICULOS\ARTICULO PUCP\RADON\LIMPIEZA_CUSCO\RO\primeros_4_periodos_RO_solo_radon_22_11.xlsx"

# Cargar el archivo Excel en un DataFrame de Pandas
df = pd.read_excel(archivo_excel)

# Obtener el valor máximo entre todos los gráficos
max_y_value = df.iloc[:, 2:].apply(pd.to_numeric, errors='coerce').max().max()

# Definir un factor para ajustar la escala máxima (por ejemplo, 1.05 para un 5% más alto)
escala_maxima_factor = 1.05

# Calcular la escala máxima ajustada
escala_maxima_ajustada = max_y_value * escala_maxima_factor

# Imprimir información para debug
print(f"Número de filas: {len(df)}")
print(f"Contenido del DataFrame:\n{df.head()}")

# Obtener el número de filas y columnas en el DataFrame
num_filas, num_columnas = df.shape

# Calcular el número de filas y columnas para los subplots
num_filas_subplot = (num_filas // 3) + (num_filas % 3 > 0)
num_columnas_subplot = 3

# Configurar subplots
fig, axs = plt.subplots(num_filas_subplot, num_columnas_subplot, figsize=(15, 4 * num_filas_subplot))

# Iterar sobre las filas y columnas
for i in range(num_filas_subplot):
    for j in range(num_columnas_subplot):
        # Calcular el índice correspondiente en el DataFrame
        index = i * num_columnas_subplot + j

        # Verificar si hay más índices que filas en el DataFrame
        if index >= num_filas:
            axs[i, j].axis('off')  # Desactivar el eje si no hay datos para ese subplot
        else:
            # Obtener datos para el eje X
            x_data = list(range(1, 5))  # Utilizar valores enteros

            # Obtener datos para el eje Y y convertir a tipo numérico
            y_data = pd.to_numeric(df.iloc[index, 2:], errors='coerce')  # Tomar todas las columnas a partir de la tercera

            # Graficar dispersión con líneas rectas y marcadores
            axs[i, j].plot(x_data, y_data, marker='o', linestyle='-')

            # Graficar barras con líneas y marcadores (ajustando el ancho de las barras)
            axs[i, j].bar(x_data, y_data, color='cornflowerblue', alpha=0.7, width=0.3, label='Barras')
            axs[i, j].plot(x_data, y_data, marker='*', linestyle='-', color='red', label='Línea con Marcadores')

            # Configurar etiquetas y título
            axs[i, j].set_xticks(x_data)  # Establecer los ticks en los valores enteros
            axs[i, j].set_xlabel('Periodo')
            axs[i, j].set_ylabel('Concentración de Radón (Bq/m3)')
            axs[i, j].set_ylim([0, escala_maxima_ajustada])  # Establecer límites en el eje Y
            axs[i, j].set_title(f'Pozo {df.iloc[index, 0]}')

# Ajustar espacio entre el título general y los subplots
plt.subplots_adjust(top=0.9)

# Agregar título general con espacio entre los subplots
plt.suptitle("RADOUT - Primeros cuatro periodos - Cusco", fontsize=16, y=0.92)

# Ajustar diseño y mostrar gráficos
plt.tight_layout(rect=[0, 0.03, 1, 0.93])
plt.show()
# Out:
# Número de filas: 18
# Contenido del DataFrame:
#    Pozo Radon and\nThoron\nMeasurement  Radon concentration_periodo_1  \
# 0     1                          RO-01                         8737.8
# 1     2                          RO-02                         6420.9
# 2     3                          RO-03                         7684.0
# 3     4                          RO-04                         8521.3
# 4     5                          RO-05                         8458.6
#
#    Radon concentration_periodo_2  Radon concentration_periodo_3  \
# 0                         9278.4                        10239.1
# 1                         6383.4                         6835.7
# 2                         8535.1                         8342.4
# 3                         9097.6                        10136.6
# 4                         9089.0                        10405.7
#
#    Radon concentration_periodo_4
# 0                         9716.5
# 1                         6556.6
# ...

# %% [markdown]
# TODO JUNTO
